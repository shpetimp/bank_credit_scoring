# %% [markdown]
# This project does exploraation of ebay car sales

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv('autos.csv' , encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# pretty small dataset, only has 7.6mb in memory. Describes cars and its features. It has 50k entries of diff cars sold. Need to convert some numeric values to numbers from objects. Some columns have lots of missing values.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
copied = autos.columns.tolist().copy()

# %%
copied
# Out:
# ['dateCrawled',
#  'name',
#  'seller',
#  'offerType',
#  'price',
#  'abtest',
#  'vehicleType',
#  'yearOfRegistration',
#  'gearbox',
#  'powerPS',
#  'model',
#  'odometer',
#  'monthOfRegistration',
#  'fuelType',
#  'brand',
#  'notRepairedDamage',
#  'dateCreated',
#  'nrOfPictures',
#  'postalCode',
#  'lastSeen']

# %%
copied = ['date_crawled',
 'name',
 'seller',
 'offer_type',
 'price',
 'abtest',
 'vehicle_type',
 'registration_year',
 'gearbox',
 'power_ps',
 'model',
 'odometer',
 'registration_month',
 'fuel_type',
 'brand',
 'unrepaired_damage',
 'ad_created',
 'nr_of_pictures',
 'postal_code',
 'last_seen']

# %%
autos.columns = copied

# %%
autos.head(2)
# Out:
#           date_crawled                                        name  seller  \
# 0  2016-03-26 17:47:46            Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1  2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
#
#   offer_type   price   abtest vehicle_type  registration_year    gearbox  \
# 0    Angebot  $5,000  control          bus               2004    manuell
# 1    Angebot  $8,500  control    limousine               1997  automatik
#
#    power_ps   model   odometer  registration_month fuel_type    brand  \
# 0       158  andere  150,000km                   3       lpg  peugeot
# 1       286     7er  150,000km                   6    benzin      bmw
#
#   unrepaired_damage           ad_created  nr_of_pictures  postal_code  \
# 0              nein  2016-03-26 00:00:00               0        79588
# 1              nein  2016-04-04 00:00:00               0        71034
#
#              last_seen
# 0  2016-04-06 06:45:54
# 1  2016-04-06 14:45:08

# %% [markdown]
# snake case is for readability.

# %%
autos.describe()
# Out:
#        registration_year      power_ps  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# registration year cant' be 1000 or 9999, nr of pics needs more closer look
# unrepaired damage is 'nein' must be 'no'. price and odometer must be numeric.

# %%
autos['odometer'] = autos['odometer'].str.replace('km', '').str.replace(',', '').astype(float)

# %%
autos['price'] = autos['price'].str.replace('$', '').str.replace(',', '').astype(int)

# %%
autos.rename({'odometer': 'odometer_km'}, inplace=True, axis=1)

# %%
autos['price'].shape
# Out:
# (50000,)

# %%
autos['odometer_km'].shape
# Out:
# (50000,)

# %%
autos['price'].unique()
# Out:
# array([ 5000,  8500,  8990, ...,   385, 22200, 16995])

# %%
autos['odometer_km'].value_counts()
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# 70000.0      1230
# 60000.0      1164
# 50000.0      1027
# 5000.0        967
# 40000.0       819
# 30000.0       789
# 20000.0       784
# 10000.0       264
# Name: odometer_km, dtype: int64

# %%
autos[['date_crawled', 'ad_created', 'last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
autos['date_crawled'].str[:7].value_counts(normalize=True)
# Out:
# 2016-03    0.8379
# 2016-04    0.1621
# Name: date_crawled, dtype: float64

# %%
autos['ad_created'].sort_index().str[:7].value_counts(normalize=False)
# Out:
# 2016-03    41866
# 2016-04     8053
# 2016-02       63
# 2016-01       12
# 2015-12        2
# 2015-06        1
# 2015-11        1
# 2015-08        1
# 2015-09        1
# Name: ad_created, dtype: int64

# %%
autos['last_seen'].sort_index().str[:7].value_counts(normalize=False)
# Out:
# 2016-04    28709
# 2016-03    21291
# Name: last_seen, dtype: int64

# %%
autos['registration_year'].sort_index().value_counts().head(3)
# Out:
# 2000    3354
# 2005    3015
# 1999    3000
# Name: registration_year, dtype: int64

# %% [markdown]
# top 3 registration years for cars are 2000, 2005,1999.

# %% [markdown]
# last seen cars are both in 2016

# %% [markdown]
# most ads are created in the first 4 months of 2016

# %% [markdown]
# highest and lowest value for registration year is 1950 and 2019 as when the cars were created and the current year

# %%
autos[autos['registration_year'] == 9999]
# Out:
#               date_crawled                                               name  \
# 8012   2016-03-23 16:43:29                      Opel_GT_Karosserie_mit_Brief!
# 14341  2016-03-23 01:36:20                                  Hole_kostenlos_ab
# 33950  2016-03-23 21:52:25  58er_karmann_ghia_lowlight_Kaefer__zum_restaur...
# 38076  2016-04-04 22:54:47                                 Mercedes_Benz_A180
#
#        seller offer_type  price abtest vehicle_type  registration_year  \
# 8012   privat    Angebot    700   test          NaN               9999
# 14341  privat    Angebot      0   test          NaN               9999
# 33950  privat    Angebot   7999   test          NaN               9999
# 38076  privat    Angebot  18000   test          NaN               9999
#
#       gearbox  power_ps     model  odometer_km  registration_month fuel_type  \
# 8012      NaN         0    andere      10000.0                   0       NaN
# ...

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer_km', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.iloc[[8012,14341,33950,38076], 7] =2019

# %%
autos['registration_year'].max()
# Out:
# 9996

# %% [markdown]
# hmm seems like after i removed 9999 year, i still have some bad years like 9996, need to check what are the max years!

# %%
autos['registration_year'].value_counts().sort_index(ascending=False)
# Out:
# 9996       1
# 9000       2
# 8888       1
# 6200       1
# 5911       1
# 5000       4
# 4800       1
# 4500       1
# 4100       1
# 2800       1
# 2019       7
# 2018     492
# 2017    1453
# 2016    1316
# 2015     399
# 2014     666
# 2013     806
# 2012    1323
# 2011    1634
# 2010    1597
# 2009    2098
# 2008    2231
# 2007    2304
# 2006    2708
# 2005    3015
# 2004    2737
# 2003    2727
# 2002    2533
# 2001    2703
# 2000    3354
#         ...
# 1963       9
# 1962       4
# 1961       6
# 1960      34
# 1959       7
# 1958       4
# 1957       2
# 1956       5
# 1955       2
# 1954       2
# 1953       1
# 1952       1
# 1951       2
# 1950       3
# 1948       1
# 1943       1
# 1941       2
# 1939       1
# 1938       1
# 1937       4
# 1934       2
# 1931       1
# 1929       1
# 1927       1
# 1910       9
# 1800       2
# 1500       1
# 1111       1
# 1001       1
# 1000       1
# Name: registration_year, Length: 96, dtype: int64

# %%
When removing outliers, we can 
do df[(df["col"] > x ) & (df["col"] < y )], but
it's more readable to use df[df["col"].between(x,y)]

# %%
bad_years = autos[autos['registration_year'] > 2019]['registration_year']

# %%
bad_years
# Out:
# 453      4500
# 4164     5000
# 4549     4100
# 6308     9996
# 8360     6200
# 13559    9000
# 22799    5000
# 24519    5000
# 25003    8888
# 27578    2800
# 27618    5911
# 42079    4800
# 49153    5000
# 49910    9000
# Name: registration_year, dtype: int64

# %%
bad_index = bad_years.tolist()

# %%
bad_index
# Out:
# [4500,
#  5000,
#  4100,
#  9996,
#  6200,
#  9000,
#  5000,
#  5000,
#  8888,
#  2800,
#  5911,
#  4800,
#  5000,
#  9000]

# %%
min_bad_years = autos[autos['registration_year'] <1950 ]['registration_year'].tolist()
#min_bad_index = min_bad_years.tolist()

# %%
min_bad_years
# Out:
# [1934,
#  1934,
#  1910,
#  1800,
#  1948,
#  1931,
#  1943,
#  1941,
#  1910,
#  1927,
#  1937,
#  1929,
#  1000,
#  1910,
#  1937,
#  1111,
#  1939,
#  1941,
#  1938,
#  1937,
#  1910,
#  1910,
#  1800,
#  1910,
#  1500,
#  1937,
#  1910,
#  1910,
#  1910,
#  1001]

# %%
autos['brand'].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
x = autos['brand'].value_counts().sort_values(ascending=False)

# %%
x = pd.DataFrame(x)

# %%
x = x.head(3)

# %%
x
# Out:
#             brand
# volkswagen  10687
# opel         5461
# bmw          5429

# %% [markdown]
# дывоадывдаоыдоаоыдвдыодоыдоаыодо

# %% [markdown]
# ыдвоадыоадыдаоыдовадыовдоафждводао209о203о
# 230ок230ао2-а0о3а-03оа20ао
# ывоа
# ывао-23оа02оавыоыдао

# %%
autos['mean_price'] = 0

# %%
autos['mean_mileage'] = 0

# %%
autos.head(3)
# Out:
#           date_crawled                                        name  seller  \
# 0  2016-03-26 17:47:46            Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1  2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
# 2  2016-03-26 18:57:24                  Volkswagen_Golf_1.6_United  privat
#
#   offer_type  price   abtest vehicle_type  registration_year    gearbox  \
# 0    Angebot   5000  control          bus               2004    manuell
# 1    Angebot   8500  control    limousine               1997  automatik
# 2    Angebot   8990     test    limousine               2009    manuell
#
#    power_ps     ...      registration_month  fuel_type       brand  \
# 0       158     ...                       3        lpg     peugeot
# 1       286     ...                       6     benzin         bmw
# 2       102     ...                       7     benzin  volkswagen
#
#   unrepaired_damage           ad_created nr_of_pictures postal_code  \
# ...

# %%
autos['seller'].value_counts()
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos[autos['seller'] == 'privat'] = 'private'

# %%
autos['seller'].value_counts()
# Out:
# private       49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos[autos['seller'] == 'gewerblich'] = 'public'

# %%
autos
# Out:
#       date_crawled     name   seller offer_type    price   abtest  \
# 0          private  private  private    private  private  private
# 1          private  private  private    private  private  private
# 2          private  private  private    private  private  private
# 3          private  private  private    private  private  private
# 4          private  private  private    private  private  private
# 5          private  private  private    private  private  private
# 6          private  private  private    private  private  private
# 7          private  private  private    private  private  private
# 8          private  private  private    private  private  private
# 9          private  private  private    private  private  private
# 10         private  private  private    private  private  private
# 11         private  private  private    private  private  private
# 12         private  private  private    private  private  private
# ...
